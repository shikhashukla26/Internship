# %%
# !pip install bs4
# !pip install requests
from bs4 import BeautifulSoup
import requests

# %%
# 1: Write a python program to display all the header tags from wikipedia.org.
page5 = requests.get('https://en.wikipedia.org')
page5
soup5 = BeautifulSoup(page5.content)
soup5
titles = soup5.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('List all the header tags :', *titles, sep='\n\n')
# Out:
# List all the header tags :
#
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none"><span class="mw-page-title-main">Main Page</span></h1>
#
# <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# ...

# %%
#) 4 :- Write s python program to display list of respected former presidents of India
page1 = requests.get('https://presidentofindia.nic.in/former-presidents.htm')
page1
soup1 = BeautifulSoup(page1.content)
soup1
first_rating = soup1.find('div',class_="presidentListing")
first_rating.text
first_rating
titles = soup1.find_all(['h3'])
titles
import pandas as pd
df = pd.DataFrame({'List of Former Presidents':titles})
df
# Out:
#                         List of Former Presidents
# 0           [Shri Ram Nath Kovind (birth - 1945)]
# 1             [Shri Pranab Mukherjee (1935-2020)]
# 2   [Smt Pratibha Devisingh Patil (birth - 1934)]
# 3            [DR. A.P.J. Abdul Kalam (1931-2015)]
# 4            [Shri K. R. Narayanan (1920 - 2005)]
# 5           [Dr Shankar Dayal Sharma (1918-1999)]
# 6               [Shri R Venkataraman (1910-2009)]
# 7                  [Giani Zail Singh (1916-1994)]
# 8         [Shri Neelam Sanjiva Reddy (1913-1996)]
# 9          [Dr. Fakhruddin Ali Ahmed (1905-1977)]
# 10     [Shri Varahagiri Venkata Giri (1894-1980)]
# 11                 [Dr. Zakir Husain (1897-1969)]
# 12     [Dr. Sarvepalli Radhakrishnan (1888-1975)]
# 13             [Dr. Rajendra Prasad (1884-1963) ]

# %%
# 5 a Top 10 ODI teams in men’s cricket along with the records for matches, points and rating
page = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
page
soup = BeautifulSoup(page.content)
soup


mat=[]
for i in soup.find_all('td', class_="table-body__cell u-center-text"):
    mat.append(i.text)
mat 
pt=[]
for i in soup.find_all('td', class_="table-body__cell u-center-text"):
    pt.append(i.text)
pt 

rank=[]
for i in soup.find_all('td', class_="table-body__cell u-text-right rating"):
    rank.append(i.text)
rank 

team=[]
for i in soup.find_all('span', class_="u-hide-phablet"):
    team.append(i.text)
team 

#import pandas as pd
#df=(pd.DataFrame({ 'Team':team }))
#df
# Out:
# ['England',
#  'New Zealand',
#  'India',
#  'Pakistan',
#  'Australia',
#  'South Africa',
#  'Bangladesh',
#  'Sri Lanka',
#  'West Indies',
#  'Afghanistan',
#  'Ireland',
#  'Scotland',
#  'Zimbabwe',
#  'Namibia',
#  'Netherlands',
#  'UAE',
#  'Oman',
#  'United States',
#  'Nepal',
#  'Papua New Guinea']

# %%
#5 b Top 10 ODI Batsmen along with the records of their team and rating.

page = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/test')
page
soup = BeautifulSoup(page.content)
soup

player=[]
for i in soup.find_all('td', class_="table-body__cell name"):
    player.append(i.text)
player 

rat=[]
for i in soup.find_all('td', class_="table-body__cell u-text-right rating"):
    rat.append(i.text)
rat 


team=[]
for i in soup.find_all('span', class_="table-body__logo-text"):
    team.append(i.text)
team 

import pandas as pd
df=(pd.DataFrame({'Player Name': player, 'Team' :team ,'Rating':rat  }))
df
# Out:
#                 Player Name Team Rating
# 0    \nMarnus Labuschagne\n  AUS    885
# 1            \nBabar Azam\n  PAK    879
# 2           \nSteve Smith\n  AUS    848
# 3          \nRishabh Pant\n  IND    801
# 4       \nKane Williamson\n   NZ    786
# 5         \nUsman Khawaja\n  AUS    766
# 6    \nDimuth Karunaratne\n   SL    748
# 7          \nRohit Sharma\n  IND    746
# 8        \nJonny Bairstow\n  ENG    719
# 9   \nRavichandran Ashwin\n  IND    842
# 10       \nShaheen Afridi\n  PAK    828
# 11       \nJasprit Bumrah\n  IND    828
# 12       \nJames Anderson\n  ENG    825
# 13        \nKagiso Rabada\n   SA    799
# 14        \nKyle Jamieson\n   NZ    788
# 15          \nKemar Roach\n   WI    756
# 16          \nNeil Wagner\n   NZ    747
# 17       \nMitchell Starc\n  AUS    739
# 18           \nBen Stokes\n  ENG    362
# 19  \nRavichandran Ashwin\n  IND    335
# 20      \nShakib Al Hasan\n  BAN    328
# 21         \nJason Holder\n   WI    323
# ...

# %%
#5 c Top 10 ODI bowlers along with the records of their team and rating


page = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')
page
soup = BeautifulSoup(page.content)
soup

player=[]
for i in soup.find_all('td', class_="table-body__cell rankings-table__name name"):
    player.append(i.text)
player 
team=[]
for i in soup.find_all('td', class_="table-body__cell rankings-table__name name"):
    team.append(i.text)
team 
rat=[]
for i in soup.find_all('td', class_="table-body__cell rating"):
    rat.append(i.text)
rat

import pandas as pd
df=(pd.DataFrame({'Player Name': player, 'Team' :team ,'Rating':rat  }))
df
# Out:
#              Player Name                  Team Rating
# 0     \nJosh Hazlewood\n    \nJosh Hazlewood\n    718
# 1   \nMujeeb Ur Rahman\n  \nMujeeb Ur Rahman\n    676
# 2     \nShaheen Afridi\n    \nShaheen Afridi\n    661
# 3      \nMohammad Nabi\n     \nMohammad Nabi\n    657
# 4       \nMehedi Hasan\n      \nMehedi Hasan\n    655
# ..                   ...                   ...    ...
# 94        \nKhawar Ali\n        \nKhawar Ali\n    398
# 95       \nSean Abbott\n       \nSean Abbott\n    398
# 96      \nNorman Vanua\n      \nNorman Vanua\n    397
# 97     \nJimmy Neesham\n     \nJimmy Neesham\n    397
# 98    \nLogan van Beek\n    \nLogan van Beek\n    394
#
# [99 rows x 3 columns]

# %%
## 6.a)  Top 10 ODI teams in women’s cricket along with the records for matches, points and rating

page = requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
page
soup = BeautifulSoup(page.content)
soup

head=[]
for i in soup.find_all('span', class_="u-hide-phablet"):
    head.append(i.text)
head 

mat=[]
for i in soup.find_all('td', class_="table-body__cell u-center-text"):
    mat.append(i.text)
mat 
point=[]
for i in soup.find_all('td', class_="table-body__cell u-center-text"):
    point.append(i.text)
point 

rat=[]
for i in soup.find_all('td', class_="table-body__cell u-text-right rating"):
    rat.append(i.text)
rat
import pandas as pd
df=(pd.DataFrame({'Team': head}))
df
# Out:
#             Team
# 0      Australia
# 1   South Africa
# 2        England
# 3          India
# 4    New Zealand
# 5    West Indies
# 6     Bangladesh
# 7       Pakistan
# 8        Ireland
# 9      Sri Lanka
# 10      Zimbabwe

# %%
# 6.b Top 10 women’s ODI Batting players along with the records of their team and rating.

page = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi')
page
soup = BeautifulSoup(page.content)
soup

name=[]
for i in soup.find_all('td', class_="table-body__cell name"):
    name.append(i.text)
name 

team=[]
for i in soup.find_all('span', class_="table-body__logo-text"):
    team.append(i.text)
team 
rat=[]
for i in soup.find_all('td', class_="table-body__cell u-text-right rating"):
    rat.append(i.text)
rat
import pandas as pd
df=(pd.DataFrame({'Player Name': name, 'Team':team,'Rating': rat}))
df
# Out:
#                 Player Name Team Rating
# 0           \nBeth Mooney\n  AUS    749
# 1       \nLaura Wolvaardt\n   SA    732
# 2        \nNatalie Sciver\n  ENG    725
# 3      \nHarmanpreet Kaur\n  IND    716
# 4       \nSmriti Mandhana\n  IND    714
# 5           \nMeg Lanning\n  AUS    710
# 6        \nRachael Haynes\n  AUS    701
# 7     \nAmy Satterthwaite\n   NZ    661
# 8   \nChamari Athapaththu\n   SL    655
# 9         \nJess Jonassen\n  AUS    725
# 10         \nMegan Schutt\n  AUS    722
# 11       \nShabnim Ismail\n   SA    722
# 12       \nJhulan Goswami\n  IND    698
# 13      \nHayley Matthews\n   WI    671
# 14           \nKate Cross\n  ENG    657
# 15       \nAyabonga Khaka\n   SA    634
# 16  \nRajeshwari Gayakwad\n  IND    617
# 17       \nMarizanne Kapp\n   SA    598
# 18         \nEllyse Perry\n  AUS    374
# 19       \nNatalie Sciver\n  ENG    357
# 20          \nAmelia Kerr\n   NZ    356
# 21       \nMarizanne Kapp\n   SA    349
# ...

# %%
# 6 . C Top 10 women’s ODI all-rounder along with the records of their team and rating.

page = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')
page
soup = BeautifulSoup(page.content)
soup

name=[]
for i in soup.find_all('td', class_="table-body__cell rankings-table__name name"):
    name.append(i.text)
name 

team=[]
for i in soup.find_all('span', class_="table-body__logo-text"):
    team.append(i.text)
team

rat=[]
for i in soup.find_all('td', class_="table-body__cell rating"):
    rat.append(i.text)
rat

import pandas as pd
df=(pd.DataFrame({'Player Name': name ,'Team': team , 'Rating':rat}))
df
# Out:
#                  Player Name Team Rating
# 0           \nEllyse Perry\n  AUS    374
# 1         \nNatalie Sciver\n  ENG    357
# 2            \nAmelia Kerr\n   NZ    356
# 3         \nMarizanne Kapp\n   SA    349
# 4          \nDeepti Sharma\n  IND    322
# 5       \nAshleigh Gardner\n  AUS    270
# 6          \nJess Jonassen\n  AUS    246
# 7         \nJhulan Goswami\n  IND    214
# 8        \nKatherine Brunt\n  ENG    207
# 9      \nSophie Ecclestone\n  ENG    201
# 10          \nRumana Ahmed\n  BAN    201
# 11              \nNida Dar\n  PAK    200
# 12  \nChloe-Lesleigh Tryon\n   SA    197
# 13       \nStafanie Taylor\n   WI    192
# 14         \nSophie Devine\n   NZ    189
# 15          \nSalma Khatun\n  BAN    178
# 16   \nChamari Athapaththu\n   SL    178
# 17        \nCharlotte Dean\n  ENG    175
# 18             \nSune Luus\n   SA    171

# %%
# 7:-Write a python program to scrape mentioned news details from https://www.cnbc.com/world/?region=world :

page = requests.get('https://www.cnbc.com/world/?region=world')
page
soup = BeautifulSoup(page.content)
soup
first_rating = soup.find('div',class_="LatestNews-headlineWrapper")
first_rating.text
first_rating
# Out:
# <div class="LatestNews-headlineWrapper"><span class="LatestNews-wrapper"><time class="LatestNews-timestamp">23 Min Ago</time></span><a class="LatestNews-headline" href="https://www.cnbc.com/2022/10/30/haunted-houses-and-horror-movies-can-reduce-stress-lower-anxiety.html" title="Haunted houses, scary movies may actually reduce stress and lower anxiety">Haunted houses, scary movies may actually reduce stress and lower anxiety</a></div>

# %%
# 8:- Write a python program to scrape the details of most downloaded articles from AI in last 90 days. 
# https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles


page4 = requests.get('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')
page4
soup4 = BeautifulSoup(page4.content)
soup4
pt = soup4.find('h2',class_="sc-1qrq3sd-1 MKjKb sc-1nmom32-0 sc-1nmom32-1 hqhUYH ebTA-dR")
pt.text
aut = soup4.find('span',class_="sc-1w3fpd7-0 pgLAT")
aut.text
pd1 = soup4.find('span',class_="sc-1thf9ly-2 bKddwo")
pd1.text 


pt=[]
for i in soup4.find_all('h2',class_="sc-1qrq3sd-1 MKjKb sc-1nmom32-0 sc-1nmom32-1 hqhUYH ebTA-dR"):
    pt.append(i.text)
pt  
aut=[]
for i in soup4.find_all('span',class_="sc-1w3fpd7-0 pgLAT"):
    aut.append(i.text)
aut 
pd1=[]
for i in soup4.find_all('span',class_="sc-1thf9ly-2 bKddwo"):
    pd1.append(i.text)
pd1
    

import pandas as pd
df=(pd.DataFrame({'Paper Title': pt,'Authors':aut,'Published Date': pd1}))
df
# Out:
#                                           Paper Title  \
# 0                                    Reward is enough
# 1                           Making sense of raw input
# 2   Law and logic: A review from an argumentation ...
# 3              Creativity and artificial intelligence
# 4   Artificial cognition for social human–robot in...
# 5   Explanation in artificial intelligence: Insigh...
# 6                       Making sense of sensory input
# 7   Conflict-based search for optimal multi-agent ...
# 8   Between MDPs and semi-MDPs: A framework for te...
# 9   The Hanabi challenge: A new frontier for AI re...
# 10  Evaluating XAI: A comparison of rule-based and...
# 11           Argumentation in artificial intelligence
# 12  Algorithms for computing strategies in two-pla...
# 13      Multiple object tracking: A literature review
# 14  Selection of relevant features and examples in...
# 15  A survey of inverse reinforcement learning: Ch...
# ...

# %%
# 9:-Write a python program to scrape mentioned details from dineout.co.in :

page3 = requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special')
page3
soup3 = BeautifulSoup(page3.content)
soup3
name = soup3.find('a',class_="restnt-name ellipsis")
name.text
rating = soup3.find('div',class_="restnt-rating rating-4")
rating.text
loc = soup3.find('div',class_="restnt-loc ellipsis")
loc.text 
price = soup3.find('span',class_="double-line-ellipsis")
price.text 

name=[]
for i in soup3.find_all('a',class_="restnt-name ellipsis"):
    name.append(i.text)
name   
rating=[]
for i in soup3.find_all('div',class_="restnt-rating rating-4"):
    rating.append(i.text)
rating 
loc=[]
for i in soup3.find_all('div',class_="restnt-loc ellipsis"):
    loc.append(i.text)
loc
price=[]
for i in soup3.find_all('span',class_="double-line-ellipsis"):
    price.append(i.text.split('|')[0])
price
Cuisine=[]
for i in soup3.find_all('span',class_="double-line-ellipsis"):
    Cuisine.append(i.text.split('|')[1])
Cuisine
images=[]
for i in soup3.find_all('img',class_="no-img"):
    images.append(i.get('data-src'))
images    
import pandas as pd
df=(pd.DataFrame({'Restaurant name': name,'Cuisine':Cuisine,'Location': loc,'Ratings':rating,'Price':price,'Images.url': images}))
df
# Out:
#                     Restaurant name                        Cuisine  \
# 0                   Castle Barbeque          Chinese, North Indian
# 1                   Jungle Jamboree   North Indian, Asian, Italian
# 2                   Castle Barbeque          Chinese, North Indian
# 3                        Cafe Knosh           Italian, Continental
# 4              The Barbeque Company          North Indian, Chinese
# 5                       India Grill          North Indian, Italian
# 6                    Delhi Barbeque                   North Indian
# 7  The Monarch - Bar Be Que Village                   North Indian
# 8                 Indian Grill Room          North Indian, Mughlai
#
#                                             Location Ratings  \
# 0                     Connaught Place, Central Delhi     4.1
# 1             3CS Mall,Lajpat Nagar - 3, South Delhi     3.9
# 2             Pacific Mall,Tagore Garden, West Delhi     3.9
# ...

# %%
# 10:-Write a python program to scrape the details of top publications 
#from Google Scholar from https://scholar.google.com/citations?view_op=top_venues&hl=en
page2 = requests.get('https://scholar.google.com/citations?view_op=top_venues&hl=en')
page2
soup2 = BeautifulSoup(page2.content)
soup2
rank = soup2.find('td',class_="gsc_mvt_p")
rank.text
pub = soup2.find('td',class_="gsc_mvt_t")
pub.text
h5i = soup2.find('a',class_="gs_ibl gsc_mp_anchor")
h5i.text 
h5m = soup2.find('span',class_="gs_ibl gsc_mp_anchor")
h5m.text 

rank=[]
for i in soup2.find_all('td',class_="gsc_mvt_p"):
    rank.append(i.text)
rank   
pub=[]
for i in soup2.find_all('td',class_="gsc_mvt_t"):
    pub.append(i.text)
pub 
h5i=[]
for i in soup2.find_all('a',class_="gs_ibl gsc_mp_anchor"):
    h5i.append(i.text)
h5i 
h5m=[]
for i in soup2.find_all('span',class_="gs_ibl gsc_mp_anchor"):
    h5m.append(i.text)
h5m 
import pandas as pd
df=(pd.DataFrame({'Rank': rank,'Publication': pub,'h5-index':h5i,'h5-median':h5m}))
df
# Out:
#     Rank                                        Publication h5-index h5-median
# 0     1.                                             Nature      444       667
# 1     2.                The New England Journal of Medicine      432       780
# 2     3.                                            Science      401       614
# 3     4.  IEEE/CVF Conference on Computer Vision and Pat...      389       627
# 4     5.                                         The Lancet      354       635
# ..   ...                                                ...      ...       ...
# 95   96.                       Journal of Business Research      145       233
# 96   97.                                   Molecular Cancer      145       209
# 97   98.                                            Sensors      145       201
# 98   99.                              Nature Climate Change      144       228
# 99  100.                    IEEE Internet of Things Journal      144       212
#
# [100 rows x 4 columns]

# %%
#2 :Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release)
# and make data frame.

from bs4 import BeautifulSoup
import requests
import re
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]
imdb = []
for index in range(0, len(movies)):
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
   print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'])
import pandas as pd    
df=(pd.DataFrame({'Rank': place,'Movie Name':movie_title,'year of release)': year}))
df
# Out:
# 1 - The Shawshank Redemption (1994) - Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman
# 2 - The Godfather (1972) - Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino
# 3 - The Dark Knight (2008) - Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger
# 4 - The Godfather Part II (1974) - Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro
# 5 - 12 Angry Men (1957) - Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb
# 6 - Schindler's List (1993) - Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes
# 7 - The Lord of the Rings: The Return of the King (2003) - Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen
# 8 - Pulp Fiction (1994) - Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman
# 9 - The Lord of the Rings: The Fellowship of the Ring (2001) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen
# ...
